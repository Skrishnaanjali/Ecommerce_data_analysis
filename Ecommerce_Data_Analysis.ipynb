# %% [markdown]
# ## ECommerce Data Analysis

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import pandas as pd
import numpy as np
edata = pd.read_csv(r'/Users/annaelizarova/Documents/GitHub/Ecommerce_data_analysis/Ecommerce_data.csv' , index_col=0)
edata.head()
# Out:
#             customer_first_name customer_last_name    category_name  \
# customer_id
# C_ID_45866                 Mary             Fuller  Office Supplies
# C_ID_44932                 Alan            Edelman  Office Supplies
# C_ID_70880                 Mary             Gayman  Office Supplies
# C_ID_33157              Raymond              Eason  Office Supplies
# C_ID_58303                 Mary           Gonzalez        Furniture
#
#                                      product_name customer_segment  \
# customer_id
# C_ID_45866                             Xerox 1913        Corporate
# C_ID_44932     #6 3/4 Gummed Flap White Envelopes        Corporate
# C_ID_70880        Belkin 8 Outlet Surge Protector         Consumer
# C_ID_33157   GBC VeloBinder Manual Binding System        Corporate
# C_ID_58303          Eldon Pizzaz Desk Accessories      Home Office
#
#             customer_city customer_state customer_country customer_region  \
# customer_id
# ...

# %%
eminus=edata[edata['profit_per_order'] < 0]

# %%
edata['delivery_status'].unique()
# Out:
# array(['Shipping on time', 'Shipping canceled', 'Late delivery',
#        'Advance shipping'], dtype=object)

# %%
import pandas as pd
import numpy as np
edata = pd.read_csv(r'/Users/annaelizarova/Documents/GitHub/Ecommerce_data_analysis/Ecommerce_data.csv' , index_col=0)
edata.head()
# Out:
#             customer_first_name customer_last_name    category_name  \
# customer_id
# C_ID_45866                 Mary             Fuller  Office Supplies
# C_ID_44932                 Alan            Edelman  Office Supplies
# C_ID_70880                 Mary             Gayman  Office Supplies
# C_ID_33157              Raymond              Eason  Office Supplies
# C_ID_58303                 Mary           Gonzalez        Furniture
#
#                                      product_name customer_segment  \
# customer_id
# C_ID_45866                             Xerox 1913        Corporate
# C_ID_44932     #6 3/4 Gummed Flap White Envelopes        Corporate
# C_ID_70880        Belkin 8 Outlet Surge Protector         Consumer
# C_ID_33157   GBC VeloBinder Manual Binding System        Corporate
# C_ID_58303          Eldon Pizzaz Desk Accessories      Home Office
#
#             customer_city customer_state customer_country customer_region  \
# customer_id
# ...

# %%
df = pd.DataFrame({'Date': edata['order_date']})
edata['order_date'] = df.Date.apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

ff = pd.DataFrame({'Date': edata['ship_date']})
edata['ship_date'] = df.Date.apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))
# Out:
# /var/folders/pj/h5dck4wj4kx0vm5wstfffc9r0000gn/T/ipykernel_42089/3148399028.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   edata['order_date'] = df.Date.apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))
# /var/folders/pj/h5dck4wj4kx0vm5wstfffc9r0000gn/T/ipykernel_42089/3148399028.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   edata['ship_date'] = df.Date.apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

# %%
edata.head()
# Out:
#             customer_first_name customer_last_name    category_name  \
# customer_id
# C_ID_45866                 Mary             Fuller  Office Supplies
# C_ID_44932                 Alan            Edelman  Office Supplies
# C_ID_70880                 Mary             Gayman  Office Supplies
# C_ID_33157              Raymond              Eason  Office Supplies
# C_ID_58303                 Mary           Gonzalez        Furniture
#
#                                      product_name customer_segment  \
# customer_id
# C_ID_45866                             Xerox 1913        Corporate
# C_ID_44932     #6 3/4 Gummed Flap White Envelopes        Corporate
# C_ID_70880        Belkin 8 Outlet Surge Protector         Consumer
# C_ID_33157   GBC VeloBinder Manual Binding System        Corporate
# C_ID_58303          Eldon Pizzaz Desk Accessories      Home Office
#
#             customer_city customer_state customer_country customer_region  \
# customer_id
# ...

# %%
edata[edata['delivery_status'] == 'Late delivery']
# Out:
#             customer_first_name customer_last_name    category_name  \
# customer_id
# C_ID_70880                 Mary             Gayman  Office Supplies
# C_ID_33157              Raymond              Eason  Office Supplies
# C_ID_58303                 Mary           Gonzalez        Furniture
# C_ID_55200                 Mary            Etezadi  Office Supplies
# C_ID_50457              Richard                Pak       Technology
# ...                         ...                ...              ...
# C_ID_34871                 Mary               Bern  Office Supplies
# C_ID_37639                  Zia            Stivers  Office Supplies
# C_ID_35727                David         Schnelling        Furniture
# C_ID_35327                Amber           Hamilton        Furniture
# C_ID_35727               Robert               Reed        Furniture
#
#                                                   product_name  \
# customer_id
# ...

# %%
eminus['category_name'].value_counts()
# Out:
# category_name
# Office Supplies    12758
# Furniture           4503
# Technology          3916
# Name: count, dtype: int64

# %%
ezero=edata[edata['profit_per_order'] == 0]
ezero['category_name'].value_counts()
# Out:
# category_name
# Office Supplies    409
# Furniture          189
# Technology         118
# Name: count, dtype: int64

# %%
edata['category_name'].value_counts()
# Out:
# category_name
# Office Supplies    68111
# Furniture          24443
# Technology         20716
# Name: count, dtype: int64

# %% [markdown]
# # Session 1 : Data Observation, Cleaning, and Preprocessing

# %% [markdown]
# ## Task 1: Load the Dataset and Basic Exploration
# - Load the Titanic dataset into a DataFrame.
# - Display the first 5 rows using `.head()`.
# - Use `.info()` to understand the structure of the dataset.
# - Use `.describe()` to get a statistical summary of the numerical columns.
#
# ### Hint:
# You can load the dataset using Pandas' `pd.read_csv()` function.

# %% [markdown]
# ## Task 2: Data Cleaning

# %% [markdown]
# ## Task 3: Handling Missing Values

# %% [markdown]
# ## Task 4: Filtering Data
